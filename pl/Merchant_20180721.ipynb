# %% [markdown]
# # 读取数据

# %%
import pandas as pd
import numpy as np

off_train = pd.read_csv('E:/tianchi/ccf_offline_stage1_train.csv')
off_test = pd.read_csv('E:/tianchi/ccf_offline_stage1_test_revised.csv')
off_train = off_train.dropna(subset = ['Coupon_id'])

# %% [markdown]
# # 添加优惠券使用天数、优惠券是在星期几领取的

# %%
import datetime

#判断使用优惠券日期-领取优惠券日期是否小于15天，小于取1，大于取0 
def days(z):
    if str(z['Date_received']) != 'nan' and str(z['Date']) != 'nan':
        days = (datetime.datetime.strptime(str(int(z['Date'])), "%Y%m%d") - datetime.datetime.strptime(str(int(z['Date_received'])), "%Y%m%d"))
        return days.days

#将判断后的结果赋值给训练集    
off_train['days'] = off_train.apply(days, axis = 1)

# %%
off_train["Week"] = off_train["Date_received"]
off_train.Week = off_train.Week.astype("int")
off_train.Week = off_train.Week.astype("str")
off_train["Week"] = pd.to_datetime(off_train["Week"]).apply(lambda x : x.weekday() + 1)

# %% [markdown]
# # 商铺优惠券领取次数

# %%
off_train.Merchant_id.value_counts()
# Out:
# 3381    122834
# 450      63042
# 760      44976
# 5341     36162
# 2709     35330
# 1569     33600
# 7555     27713
# 4660     24867
# 6454     21575
# 3621     20779
# 1433     20467
# 2099     16824
# 6434     16529
# 4663     15191
# 1469     14531
# 4860     14102
# 7019     14004
# 6901     13886
# 6485     13439
# 5717     12875
# 6284     10624
# 2934     10533
# 2146     10075
# 3532     10066
# 8386      9917
# 1080      9138
# 2436      8831
# 7974      8753
# 1041      8687
# 1520      8595
#          ...
# 3653         1
# 1518         1
# 7865         1
# 6244         1
# 5352         1
# 6920         1
# 3306         1
# 494          1
# 2591         1
# 3397         1
# 5068         1
# 4594         1
# 7209         1
# 7385         1
# 7276         1
# 2843         1
# 2378         1
# 8299         1
# 3183         1
# 1471         1
# 5650         1
# 6191         1
# 5565         1
# 8409         1
# 7493         1
# 8297         1
# 5444         1
# ...

# %%
off_train.Merchant_id.value_counts()[0:1400]

# %% [markdown]
# # 商铺优惠券领取次数前5、后10

# %%
off_train[off_train.Merchant_id == 3381].sort_values(by='Discount_rate').to_csv('E:/tianchi/20180721/Merchant_1.csv', index=None)

# %%
off_train[off_train.Merchant_id == 450].sort_values(by='Discount_rate').to_csv('E:/tianchi/20180721/Merchant_2.csv', index=None)

# %%
off_train[off_train.Merchant_id == 760].sort_values(by='Discount_rate').to_csv('E:/tianchi/20180721/Merchant_3.csv', index=None)

# %%
off_train[off_train.Merchant_id == 5341].sort_values(by='Discount_rate').to_csv('E:/tianchi/20180721/Merchant_4.csv', index=None)

# %%
off_train[off_train.Merchant_id == 2709].sort_values(by='Discount_rate').to_csv('E:/tianchi/20180721/Merchant_5.csv', index=None)

# %%
off_train[off_train.Merchant_id == 3381].Week.value_counts()
# Out:
# 5    32746
# 4    21973
# 6    15803
# 7    14340
# 1    13817
# 2    12875
# 3    11280
# Name: Week, dtype: int64

# %%
off_train[off_train.Merchant_id == 450].Week.value_counts()
# Out:
# 3    10601
# 1    10453
# 5     9248
# 4     9145
# 2     8116
# 7     7868
# 6     7611
# Name: Week, dtype: int64

# %%
off_train[off_train.Merchant_id == 760].Week.value_counts()
# Out:
# 3    8281
# 4    6694
# 1    6587
# 6    6174
# 2    5983
# 5    5694
# 7    5563
# Name: Week, dtype: int64

# %%
off_train[off_train.Merchant_id == 5341].Week.value_counts()
# Out:
# 7    17427
# 6     3836
# 5     3653
# 1     3436
# 3     2877
# 4     2680
# 2     2253
# Name: Week, dtype: int64

# %%
off_train[off_train.Merchant_id == 2709].Week.value_counts()
# Out:
# 1    6430
# 3    6154
# 7    5605
# 4    5148
# 2    4436
# 6    4255
# 5    3302
# Name: Week, dtype: int64

# %%
off_train.Week.value_counts()
# Out:
# 7    192614
# 5    168071
# 1    162069
# 6    160211
# 4    132771
# 3    122754
# 2    114792
# Name: Week, dtype: int64

# %%
off_train[off_train.Merchant_id == 454]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1690544  6986183          454    12946.0          50:5       NaN
#
#          Date_received  Date  days  Week
# 1690544     20160605.0   NaN   NaN     7

# %%
off_train[off_train.Merchant_id == 5165]
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 364373  5698406         5165    12985.0          20:1       0.0
#
#         Date_received  Date  days  Week
# 364373     20160614.0   NaN   NaN     2

# %%
off_train[off_train.Merchant_id == 6188]
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 791003  1685851         6188     9862.0          20:1       0.0
#
#         Date_received  Date  days  Week
# 791003     20160513.0   NaN   NaN     5

# %%
off_train[off_train.Merchant_id == 5444]
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 636907  6006644         5444    10571.0          50:5       0.0
#
#         Date_received  Date  days  Week
# 636907     20160513.0   NaN   NaN     5

# %%
off_train[off_train.Merchant_id == 8297]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1543835  6869910         8297     1166.0          20:1       NaN
#
#          Date_received  Date  days  Week
# 1543835     20160420.0   NaN   NaN     3

# %%
off_train[off_train.Merchant_id == 7493]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1737416  6108804         7493     1175.0          0.95       0.0
#
#          Date_received  Date  days  Week
# 1737416     20160128.0   NaN   NaN     4

# %%
off_train[off_train.Merchant_id == 8409]
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 608031  6516500         8409    11880.0          10:1       NaN
#
#         Date_received  Date  days  Week
# 608031     20160521.0   NaN   NaN     6

# %%
off_train[off_train.Merchant_id == 5565]
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 727890  4966556         5565     4514.0           0.9       0.0
#
#         Date_received  Date  days  Week
# 727890     20160316.0   NaN   NaN     3

# %%
off_train[off_train.Merchant_id == 6191]
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 193206  3388064         6191    14025.0          20:1       5.0
#
#         Date_received  Date  days  Week
# 193206     20160305.0   NaN   NaN     6

# %%
off_train[off_train.Merchant_id == 5650]
# Out:
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 887628  5212501         5650    10708.0          30:1       3.0
#
#         Date_received        Date  days  Week
# 887628     20160612.0  20160622.0  10.0     7

# %%
off_train[off_train.Merchant_id == 3381].days.value_counts()
# Out:
# 0.0     230
# 1.0     192
# 2.0     152
# 5.0     102
# 4.0     101
# 7.0      96
# 6.0      94
# 3.0      94
# 8.0      85
# 12.0     72
# 30.0     68
# 22.0     66
# 13.0     66
# 29.0     64
# 23.0     60
# 16.0     60
# 14.0     59
# 21.0     59
# 20.0     59
# 17.0     56
# 10.0     54
# 11.0     53
# 31.0     53
# 15.0     53
# 18.0     52
# 9.0      50
# 19.0     49
# 24.0     43
# 27.0     41
# 26.0     40
# 28.0     39
# 25.0     38
# 32.0     20
# 34.0     14
# 33.0     12
# 36.0      9
# 35.0      8
# 37.0      5
# 41.0      4
# 40.0      4
# 42.0      3
# 38.0      3
# 39.0      3
# 43.0      1
# 44.0      1
# Name: days, dtype: int64

# %%
off_train[off_train.Merchant_id == 450].days.value_counts()
# Out:
# 1.0     105
# 3.0      93
# 4.0      91
# 2.0      86
# 6.0      80
# 5.0      77
# 7.0      69
# 0.0      68
# 8.0      67
# 10.0     48
# 16.0     46
# 9.0      44
# 13.0     40
# 11.0     39
# 17.0     37
# 15.0     35
# 14.0     34
# 12.0     34
# 18.0     32
# 19.0     32
# 22.0     30
# 21.0     29
# 20.0     28
# 23.0     28
# 25.0     27
# 24.0     22
# 27.0     18
# 26.0     16
# 30.0     14
# 28.0     14
# 33.0     12
# 31.0     11
# 29.0      9
# 32.0      9
# 35.0      6
# 37.0      5
# 36.0      5
# 40.0      4
# 34.0      4
# 38.0      4
# 39.0      4
# 42.0      2
# 44.0      1
# 43.0      1
# 41.0      1
# Name: days, dtype: int64

# %%
off_train[off_train.Merchant_id == 760].days.value_counts()
# Out:
# 1.0     272
# 3.0     244
# 2.0     243
# 8.0     233
# 4.0     218
# 7.0     217
# 6.0     216
# 9.0     197
# 5.0     190
# 0.0     174
# 10.0    147
# 11.0     72
# 12.0     64
# 14.0     56
# 15.0     51
# 18.0     51
# 22.0     51
# 17.0     49
# 13.0     49
# 16.0     42
# 20.0     39
# 23.0     32
# 21.0     30
# 25.0     28
# 26.0     28
# 19.0     27
# 24.0     24
# 27.0     16
# 28.0     16
# 29.0     12
# 35.0     10
# 33.0      9
# 34.0      8
# 30.0      8
# 31.0      7
# 32.0      5
# 37.0      3
# 36.0      2
# Name: days, dtype: int64

# %%
off_train[off_train.Merchant_id == 5341].days.value_counts()
# Out:
# 1.0     595
# 0.0     549
# 2.0     441
# 3.0     349
# 4.0     267
# 6.0     248
# 5.0     224
# 8.0     214
# 7.0     209
# 9.0     172
# 10.0    166
# 12.0    163
# 15.0    161
# 13.0    153
# 14.0    153
# 11.0    152
# 21.0    148
# 17.0    124
# 16.0    114
# 22.0    111
# 19.0    105
# 18.0    104
# 20.0     94
# 28.0     75
# 23.0     74
# 25.0     74
# 27.0     65
# 24.0     61
# 29.0     60
# 26.0     59
# 30.0     35
# 32.0     30
# 31.0     28
# 33.0     21
# 35.0     21
# 34.0     19
# 36.0      9
# 37.0      6
# Name: days, dtype: int64

# %%
off_train[off_train.Merchant_id == 2709].days.value_counts()
# Out:
# 0.0     24
# 24.0    10
# 15.0     9
# 13.0     8
# 3.0      8
# 1.0      8
# 4.0      7
# 21.0     7
# 10.0     7
# 26.0     7
# 12.0     7
# 14.0     6
# 20.0     6
# 18.0     6
# 25.0     6
# 17.0     6
# 34.0     5
# 5.0      5
# 19.0     5
# 2.0      5
# 6.0      4
# 32.0     4
# 7.0      4
# 29.0     4
# 8.0      4
# 16.0     3
# 23.0     3
# 22.0     3
# 31.0     3
# 28.0     3
# 11.0     3
# 35.0     3
# 9.0      3
# 40.0     2
# 41.0     2
# 27.0     2
# 39.0     2
# 33.0     1
# 51.0     1
# 42.0     1
# 38.0     1
# 37.0     1
# 30.0     1
# Name: days, dtype: int64

# %% [markdown]
# # 发放优惠券与月份

# %%
off_train[off_train.Merchant_id == 3381][off_train[off_train.Merchant_id == 3381].Date_received.apply(lambda x: 20160100 < x < 20160132)]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 8        2029232         3381    11951.0        200:20       1.0
# 16       2223968         3381     9776.0          10:5       2.0
# 45       4061024         3381     9776.0          10:5      10.0
# 57       4717248         3381    11951.0        200:20       4.0
# 99        114747         3381    11951.0        200:20       0.0
# 100       114747         3381     9776.0          10:5       0.0
# 155      1707440         3381    11951.0        200:20       1.0
# 170        65787         3381    11951.0        200:20       3.0
# 173       127227         3381     9776.0          10:5       1.0
# 176       127227         3381    11951.0        200:20       1.0
# 200       886872         3381    11951.0        200:20       2.0
# 201       886872         3381     9776.0          10:5       2.0
# 215       476332         3381     9776.0          10:5       0.0
# ...

# %%
off_train[off_train.Merchant_id == 3381]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 7        1832624         3381     7610.0        200:20       0.0
# 8        2029232         3381    11951.0        200:20       1.0
# 16       2223968         3381     9776.0          10:5       2.0
# 20         94107         3381     7610.0        200:20       2.0
# 43       4061024         3381     7610.0        200:20      10.0
# 45       4061024         3381     9776.0          10:5      10.0
# 47       7073472         3381     7610.0        200:20       0.0
# 57       4717248         3381    11951.0        200:20       4.0
# 99        114747         3381    11951.0        200:20       0.0
# 100       114747         3381     9776.0          10:5       0.0
# 141       984408         3381     1807.0        300:30       0.0
# 155      1707440         3381    11951.0        200:20       1.0
# 170        65787         3381    11951.0        200:20       3.0
# ...

# %% [markdown]
# # 优惠券是比率还是满减型，处理方式为比率型填为空

# %%
import re
regex = re.compile('^\d+:\d+$')

def drop_discountrate(z):
    if re.match(regex, str(z['Discount_rate'])):
        return z['Discount_rate']
    else:
        return np.NaN
    
off_train['Discount_rate'] = off_train.apply(drop_discountrate, axis=1)

# %%
off_train.dropna(subset=['Discount_rate'])

# %% [markdown]
# # 商铺优惠券领取25、50、75分位数(按顺序)

# %%
off_train[off_train.Merchant_id == 6429]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 36718    2989982         6429     1931.0          30:1       NaN
# 36719    2989982         6429     1931.0          30:1       NaN
# 1544587  2463695         6429     1931.0          30:1       NaN
# 1544589  2463695         6429     1931.0          30:1       NaN
# 1720781  4718160         6429     1931.0          30:1       NaN
#
#          Date_received        Date  days  Week
# 36718       20160531.0  20160606.0   6.0     2
# 36719       20160606.0         NaN   NaN     1
# 1544587     20160530.0  20160601.0   2.0     1
# 1544589     20160601.0         NaN   NaN     3
# 1720781     20160522.0         NaN   NaN     7

# %%
off_train[off_train.Merchant_id == 3211]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 126212   2717744         3211     1864.0          20:1       0.0
# 211987    136588         3211     1864.0          20:1       NaN
# 257725   6957677         3211     1864.0          20:1       1.0
# 326961   3036975         3211     1864.0          20:1       0.0
# 331341   2501439         3211     1864.0          20:1       0.0
# 582136    176630         3211     1864.0          20:1       6.0
# 906119   4317754         3211     1864.0          20:1       3.0
# 1258862   335999         3211     1864.0          20:1       NaN
# 1264098    22308         3211     1864.0          20:1       0.0
# 1557148  2244089         3211     1864.0          20:1       0.0
#
#          Date_received        Date  days  Week
# 126212      20160418.0         NaN   NaN     1
# 211987      20160423.0  20160514.0  21.0     6
# 257725      20160419.0         NaN   NaN     2
# 326961      20160403.0         NaN   NaN     7
# ...

# %%
off_train[off_train.Merchant_id == 4919]
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 31274    2050250         4919      995.0          10:1       2.0
# 31280    2050250         4919      995.0          10:1       2.0
# 31282    2050250         4919      995.0          10:1       2.0
# 31287    2050250         4919      995.0          10:1       2.0
# 289670   6538361         4919     7461.0          10:1       3.0
# 431638   4282682         4919     7461.0          10:1       0.0
# 586811   1649587         4919     7461.0          10:1       0.0
# 639817   7017344         4919      995.0          10:1       0.0
# 876531   5489821         4919     7461.0          10:1       0.0
# 1050334  5628519         4919     7461.0          10:1       0.0
# 1110888  2793730         4919      995.0          10:1       0.0
# 1110889  2793730         4919    11462.0          10:1       0.0
# 1116699  1183878         4919      995.0          10:1       NaN
# ...

# %% [markdown]
# # 商铺被使用优惠券次数

# %%
User_Coupon_notna = off_train.dropna(subset=['Date'])

# %%
User_Coupon_notna.Merchant_id.value_counts()
# Out:
# 5341    5653
# 760     3140
# 6485    3119
# 3381    2487
# 2099    1705
# 2934    1611
# 450     1461
# 4142    1403
# 7555    1353
# 3532    1315
# 3621    1117
# 1520    1108
# 6901     994
# 797      988
# 1433     740
# 1379     732
# 1469     679
# 6135     676
# 7910     659
# 2436     626
# 7903     572
# 3284     557
# 7717     554
# 8775     498
# 3786     491
# 8181     482
# 7422     480
# 1169     478
# 3283     469
# 3710     465
#         ...
# 1823       1
# 7708       1
# 5276       1
# 1439       1
# 1438       1
# 6108       1
# 2014       1
# 8219       1
# 4125       1
# 2078       1
# 159        1
# 6364       1
# 223        1
# 4573       1
# 543        1
# 8795       1
# 4765       1
# 671        1
# 6876       1
# 735        1
# 6940       1
# 2846       1
# 799        1
# 7004       1
# 991        1
# 1183       1
# 7516       1
# 1375       1
# 3486       1
# 2113       1
# Name: Merchant_id, Length: 4076, dtype: int64

# %%
User_Coupon_notna.Merchant_id.value_counts()[0:1019]

# %% [markdown]
# # 商铺优惠券被使用次数前5、后10

# %%
User_Coupon_notna[off_train.Merchant_id == 5341].sort_values(by='User_id').to_csv('E:/tianchi/20180721/Consume_1.csv', index=None)

# %%
User_Coupon_notna[off_train.Merchant_id == 760].sort_values(by='User_id').to_csv('E:/tianchi/20180721/Consume_2.csv', index=None)

# %%
User_Coupon_notna[off_train.Merchant_id == 6485].sort_values(by='User_id').to_csv('E:/tianchi/20180721/Consume_3.csv', index=None)

# %%
User_Coupon_notna[off_train.Merchant_id == 3381].sort_values(by='User_id').to_csv('E:/tianchi/20180721/Consume_4.csv', index=None)

# %%
User_Coupon_notna[off_train.Merchant_id == 2099].sort_values(by='User_id').to_csv('E:/tianchi/20180721/Consume_5.csv', index=None)

# %%
User_Coupon_notna[off_train.Merchant_id == 5341].Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 7    1760
# 6     846
# 1     711
# 5     674
# 4     622
# 3     572
# 2     468
# Name: Week, dtype: int64

# %%
User_Coupon_notna[off_train.Merchant_id == 760].Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 3    610
# 5    473
# 6    441
# 2    425
# 7    410
# 1    402
# 4    379
# Name: Week, dtype: int64

# %%
User_Coupon_notna[off_train.Merchant_id == 6485].Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 2    512
# 1    453
# 3    451
# 5    446
# 7    444
# 6    436
# 4    377
# Name: Week, dtype: int64

# %%
User_Coupon_notna[off_train.Merchant_id == 3381].Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 5    1197
# 6     288
# 4     274
# 7     241
# 1     197
# 2     152
# 3     138
# Name: Week, dtype: int64

# %%
User_Coupon_notna[off_train.Merchant_id == 2099].Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 7    620
# 5    242
# 6    194
# 3    185
# 4    181
# 1    171
# 2    112
# Name: Week, dtype: int64

# %%
User_Coupon_notna.Week.value_counts()
# Out:
# 5    12168
# 7    11552
# 6    10964
# 1    10536
# 3    10449
# 2     9901
# 4     9812
# Name: Week, dtype: int64

# %%
User_Coupon_notna[off_train.Merchant_id == 2113]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1315392   664724         2113      326.0          0.95       0.0
#
#          Date_received        Date  days  Week
# 1315392     20160503.0  20160503.0   0.0     2

# %%
User_Coupon_notna[off_train.Merchant_id == 3486]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 583938   183350         3486     3644.0          50:5       0.0
#
#         Date_received        Date  days  Week
# 583938     20160609.0  20160622.0  13.0     4

# %%
User_Coupon_notna[off_train.Merchant_id == 1375]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 958370  7288750         1375       70.0        100:10       1.0
#
#         Date_received        Date  days  Week
# 958370     20160610.0  20160615.0   5.0     5

# %%
User_Coupon_notna[off_train.Merchant_id == 7516]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 934892  4576006         7516     3245.0        100:10       1.0
#
#         Date_received        Date  days  Week
# 934892     20160519.0  20160521.0   2.0     4

# %%
User_Coupon_notna[off_train.Merchant_id == 1183]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 658304  2963934         1183    11096.0          50:1       0.0
#
#         Date_received        Date  days  Week
# 658304     20160613.0  20160613.0   0.0     1

# %%
User_Coupon_notna[off_train.Merchant_id == 991]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1161986  2183512          991    11612.0        100:30       5.0
#
#          Date_received        Date  days  Week
# 1161986     20160517.0  20160522.0   5.0     2

# %%
User_Coupon_notna[off_train.Merchant_id == 7004]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1417630  3811066         7004    10539.0          20:1       1.0
#
#          Date_received        Date  days  Week
# 1417630     20160515.0  20160521.0   6.0     7

# %%
User_Coupon_notna[off_train.Merchant_id == 799]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 388535  2360841          799    12306.0          50:5       2.0
#
#         Date_received        Date  days  Week
# 388535     20160511.0  20160521.0  10.0     3

# %%
User_Coupon_notna[off_train.Merchant_id == 2846]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1566049  2942999         2846    11348.0        100:30       0.0
#
#          Date_received        Date  days  Week
# 1566049     20160520.0  20160612.0  23.0     5

# %%
User_Coupon_notna[off_train.Merchant_id == 6940]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1734366   709200         6940     5682.0        100:10      10.0
#
#          Date_received        Date  days  Week
# 1734366     20160604.0  20160619.0  15.0     6

# %% [markdown]
# # 商铺优惠券被使用次数75、50、25分位数（按顺序）

# %%
User_Coupon_notna[off_train.Merchant_id == 857]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 992507   2984527          857     7692.0        100:30      10.0
# 992509   2984527          857     7692.0        100:30      10.0
# 992511   2984527          857     7692.0        100:30      10.0
# 1509067  3949907          857     7692.0        100:30      10.0
# 1509069  3949907          857     9154.0        100:20      10.0
# 1509079  3949907          857     9154.0        100:20      10.0
#
#          Date_received        Date  days  Week
# 992507      20160515.0  20160516.0   1.0     7
# 992509      20160514.0  20160515.0   1.0     6
# 992511      20160516.0  20160519.0   3.0     1
# 1509067     20160512.0  20160513.0   1.0     4
# 1509069     20160428.0  20160512.0  14.0     4
# ...

# %%
User_Coupon_notna[off_train.Merchant_id == 2957]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 668570  1801207         2957     2067.0        100:20       0.0
# 668572  1801207         2957     2067.0        100:20       0.0
# 668573  1801207         2957     2067.0        100:20       0.0
#
#         Date_received        Date  days  Week
# 668570     20160506.0  20160507.0   1.0     5
# 668572     20160504.0  20160505.0   1.0     3
# 668573     20160505.0  20160506.0   1.0     4

# %%
User_Coupon_notna[off_train.Merchant_id == 77]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 383720  4783082           77       67.0          20:1       0.0
#
#         Date_received        Date  days  Week
# 383720     20160322.0  20160327.0   5.0     2

# %% [markdown]
# # 商铺没有被使用优惠券次数

# %%
not_used = off_train[off_train.Date.isnull()]

# %%
not_used.Merchant_id.value_counts()
# Out:
# 3381    120347
# 450      61581
# 760      41836
# 2709     35120
# 1569     33448
# 5341     30509
# 7555     26360
# 4660     24836
# 6454     21468
# 1433     19727
# 3621     19662
# 6434     16343
# 2099     15119
# 4663     15115
# 4860     13971
# 7019     13963
# 1469     13852
# 6901     12892
# 5717     12581
# 6284     10583
# 6485     10320
# 2146      9978
# 8386      9825
# 1080      8945
# 2934      8922
# 3532      8751
# 7974      8375
# 1041      8283
# 4833      8205
# 2436      8205
#          ...
# 8817         1
# 5276         1
# 2035         1
# 6218         1
# 733          1
# 1245         1
# 1757         1
# 675          1
# 4963         1
# 783          1
# 2633         1
# 8268         1
# 1568         1
# 7900         1
# 630          1
# 1294         1
# 5388         1
# 4007         1
# 2720         1
# 827          1
# 5079         1
# 5469         1
# 6772         1
# 316          1
# 920          1
# 7004         1
# 8631         1
# ...

# %%
not_used.Merchant_id.value_counts()[0:1370]

# %% [markdown]
# # 商铺优惠券没有被使用次数前5、后10

# %%
not_used[off_train.Merchant_id == 3381].sort_values(by='User_id').to_csv('E:/tianchi/20180721/notused_1.csv', index=None)

# %%
not_used[off_train.Merchant_id == 450].sort_values(by='User_id').to_csv('E:/tianchi/20180721/notused_2.csv', index=None)

# %%
not_used[off_train.Merchant_id == 760].sort_values(by='User_id').to_csv('E:/tianchi/20180721/notused_3.csv', index=None)

# %%
not_used[off_train.Merchant_id == 2709].sort_values(by='User_id').to_csv('E:/tianchi/20180721/notused_4.csv', index=None)

# %%
not_used[off_train.Merchant_id == 1569].sort_values(by='User_id').to_csv('E:/tianchi/20180721/notused_5.csv', index=None)

# %%
not_used[off_train.Merchant_id == 3381].sort_values(by='User_id').Discount_rate.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 200:20    82543
# 300:30    28428
# 10:5       9376
# Name: Discount_rate, dtype: int64

# %%
not_used[off_train.Merchant_id == 450].sort_values(by='User_id').Discount_rate.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 30:5      60285
# 20:5       1006
# 100:1        97
# 100:5        96
# 100:10       46
# 30:10        38
# 0.9          11
# 0.95          2
# Name: Discount_rate, dtype: int64

# %%
not_used[off_train.Merchant_id == 760].sort_values(by='User_id').Discount_rate.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 30:5    30085
# 20:5    11662
# 0.95       89
# Name: Discount_rate, dtype: int64

# %%
not_used[off_train.Merchant_id == 2709].sort_values(by='User_id').Discount_rate.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 100:10    30041
# 200:20     4786
# 100:30      147
# 0.95        140
# 0.9           5
# 0.85          1
# Name: Discount_rate, dtype: int64

# %%
not_used[off_train.Merchant_id == 1569].sort_values(by='User_id').Discount_rate.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 200:30    21381
# 100:30    11302
# 0.9         293
# 30:5        221
# 0.8         168
# 50:5         74
# 200:50        9
# Name: Discount_rate, dtype: int64

# %%
not_used[off_train.Merchant_id == 3381].sort_values(by='User_id').Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 5    31549
# 4    21699
# 6    15515
# 7    14099
# 1    13620
# 2    12723
# 3    11142
# Name: Week, dtype: int64

# %%
not_used[off_train.Merchant_id == 450].sort_values(by='User_id').Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 3    10344
# 1    10239
# 5     9026
# 4     8916
# 2     7934
# 7     7673
# 6     7449
# Name: Week, dtype: int64

# %%
not_used[off_train.Merchant_id == 760].sort_values(by='User_id').Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 3    7671
# 4    6315
# 1    6185
# 6    5733
# 2    5558
# 5    5221
# 7    5153
# Name: Week, dtype: int64

# %%
not_used[off_train.Merchant_id == 2709].sort_values(by='User_id').Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 1    6409
# 3    6120
# 7    5569
# 4    5125
# 2    4404
# 6    4224
# 5    3269
# Name: Week, dtype: int64

# %%
not_used[off_train.Merchant_id == 1569].sort_values(by='User_id').Week.value_counts()
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 7    5111
# 1    5035
# 3    5000
# 4    4706
# 5    4657
# 2    4616
# 6    4323
# Name: Week, dtype: int64

# %%
not_used[off_train.Merchant_id == 705]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 137431  1177121          705      741.0          20:1       0.0
#
#         Date_received  Date  days  Week
# 137431     20160517.0   NaN   NaN     2

# %%
not_used[off_train.Merchant_id == 1252]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        User_id  Merchant_id  Coupon_id Discount_rate  Distance  Date_received  \
# 31175  3955604         1252     9961.0          30:1       NaN     20160614.0
#
#        Date  days  Week
# 31175   NaN   NaN     2

# %%
not_used[off_train.Merchant_id == 6267]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1318084  1234731         6267     3914.0          30:1       0.0
#
#          Date_received  Date  days  Week
# 1318084     20160509.0   NaN   NaN     1

# %%
not_used[off_train.Merchant_id == 8631]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1262202  3846652         8631     4971.0          10:1       0.0
#
#          Date_received  Date  days  Week
# 1262202     20160511.0   NaN   NaN     3

# %%
not_used[off_train.Merchant_id == 7004]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        User_id  Merchant_id  Coupon_id Discount_rate  Distance  Date_received  \
# 98450    70608         7004    10539.0          20:1       1.0     20160514.0
#
#        Date  days  Week
# 98450   NaN   NaN     6

# %%
not_used[off_train.Merchant_id == 920]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1485924  2397443          920     7711.0          20:1       0.0
#
#          Date_received  Date  days  Week
# 1485924     20160612.0   NaN   NaN     7

# %%
not_used[off_train.Merchant_id == 316]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1432504  6212289          316     8848.0           0.9       2.0
#
#          Date_received  Date  days  Week
# 1432504     20160330.0   NaN   NaN     3

# %%
not_used[off_train.Merchant_id == 6772]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 219496  2271434         6772     7017.0          20:5       NaN
#
#         Date_received  Date  days  Week
# 219496     20160320.0   NaN   NaN     7

# %%
not_used[off_train.Merchant_id == 5469]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1470061  5453073         5469     5069.0          10:1       NaN
#
#          Date_received  Date  days  Week
# 1470061     20160610.0   NaN   NaN     5

# %%
not_used[off_train.Merchant_id == 5079]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 1395235  1230954         5079     5161.0          20:1       0.0
#
#          Date_received  Date  days  Week
# 1395235     20160528.0   NaN   NaN     6

# %% [markdown]
# # 商铺优惠券没有被使用次数75、50、25分位数（按顺序）

# %%
not_used[off_train.Merchant_id == 1171]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 456944   5601770         1171    11519.0        100:30      10.0
# 662633   3415524         1171    11519.0        100:30       0.0
# 1144701  1045199         1171    11519.0        100:30       NaN
# 1606054  3635879         1171    11519.0        100:30       4.0
#
#          Date_received  Date  days  Week
# 456944      20160521.0   NaN   NaN     6
# 662633      20160520.0   NaN   NaN     5
# 1144701     20160523.0   NaN   NaN     1
# 1606054     20160525.0   NaN   NaN     3

# %%
not_used[off_train.Merchant_id == 770]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 29242     300466          770    11339.0          30:5       0.0
# 58764    1030896          770     7271.0          50:5       8.0
# 81059    3189734          770     7271.0          50:5       0.0
# 84887     962811          770     7271.0          50:5       NaN
# 490831   5032939          770     7271.0          50:5       0.0
# 640892     33159          770    11339.0          30:5       0.0
# 791167   5746028          770    11339.0          30:5       NaN
# 1024341  2270395          770     7271.0          50:5       0.0
# 1522090  4087679          770     7271.0          50:5       0.0
#
#          Date_received  Date  days  Week
# 29242       20160512.0   NaN   NaN     4
# ...

# %%
not_used[off_train.Merchant_id == 2975]
# Out:
# C:\Users\pulei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 238676   3023594         2975    13953.0          20:1       1.0
# 469959   5730979         2975    13953.0          20:1       5.0
# 469960   5730979         2975      769.0          20:5       5.0
# 478823   5764903         2975    13953.0          20:1      10.0
# 478825   5764903         2975      769.0          20:5      10.0
# 528822   1961347         2975    13953.0          20:1       0.0
# 611721    221945         2975    13953.0          20:1       NaN
# 738076   6173888         2975    13953.0          20:1       0.0
# 883543   5795089         2975    13953.0          20:1       0.0
# 948846   4553578         2975    13953.0          20:1       1.0
# ...
